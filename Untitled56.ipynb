# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagveer1234/EDA-in-Hospitality-Domain/blob/main/Untitled56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_bookings=pd.read_csv('/content/fact_bookings.csv')

# %%
df_bookings.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1             9100.0            3640.0
# 4            10920.0           10920.0

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4', nan], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline', nan], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            18825
# makeyourtrip       9166
# logtrip            5035
# direct online      4512
# tripster           3280
# journey            2751
# direct offline     2328
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#         property_id     no_guests  ratings_given  revenue_generated  \
# count  45898.000000  45894.000000   19216.000000       4.589700e+04
# mean   18063.787420      2.033033       3.625468       1.604124e+04
# std     1092.604849      1.033148       1.232011       1.520823e+05
# min    16558.000000    -12.000000       1.000000       6.500000e+03
# 25%    17558.000000      1.000000       3.000000       9.900000e+03
# 50%    17564.000000      2.000000       4.000000       1.350000e+04
# 75%    18563.000000      2.000000       5.000000       1.800000e+04
# max    19563.000000      6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count      45897.000000
# mean       12681.857507
# std         6924.028639
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date=pd.read_csv('/content/dim_date.csv')
df_hotel=pd.read_csv('/content/dim_hotels.csv')
df_room=pd.read_csv('/content/dim_rooms.csv')
df_agg_bookings=pd.read_csv('/content/fact_aggregated_bookings.csv')

# %%
df_hotel.shape
# Out:
# (25, 4)

# %%
df_hotel.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotel.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotel.city.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='city'>

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
df_agg_bookings.property_id.value_counts()
# Out:
# property_id
# 16559    368
# 17559    368
# 17564    368
# 19561    368
# 19559    368
# 18563    368
# 18562    368
# 18561    368
# 18559    368
# 18558    368
# 17563    368
# 17562    368
# 16563    368
# 19562    368
# 16562    368
# 16561    368
# 16560    368
# 17561    368
# 19560    368
# 19558    368
# 17560    368
# 16558    368
# 17558    368
# 19563    368
# 18560    368
# Name: count, dtype: int64

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_agg_bookings.capacity.max(),df_agg_bookings.capacity.min()
# Out:
# (50.0, 3.0)

# %% [markdown]
# #Data Cleaning

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#               booking_id  property_id booking_date check_in_date  \
# 0       May012216558RT11        16558     27-04-22      1/5/2022
# 3       May012216558RT14        16558     28-04-22      1/5/2022
# 17924   May122218559RT44        18559    12/5/2022     12/5/2022
# 18020   May122218561RT22        18561     8/5/2022     12/5/2022
# 18119  May122218562RT311        18562     5/5/2022     12/5/2022
# 18121  May122218562RT313        18562    10/5/2022     12/5/2022
#
#       checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0          2/5/2022       -3.0           RT1    direct online            1.0
# 3          2/5/2022       -2.0           RT1           others            NaN
# 17924      14-05-22      -10.0           RT4    direct online            NaN
# 18020      14-05-22      -12.0           RT2     makeyourtrip            NaN
# 18119      17-05-22       -6.0           RT3   direct offline            5.0
# ...

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]
df_bookings.shape
# Out:
# (45888, 12)

# %%
avg, std =df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
avg, std
# Out:
# (16041.597258542539, 152097.217750529)

# %%
higher_limit=avg  + 3*std
higher_limit
# Out:
# 472333.25051012955

# %%
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings
# Out:
#              booking_id  property_id booking_date check_in_date checkout_date  \
# 1      May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4      May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5      May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6      May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7      May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# ...                 ...          ...          ...           ...           ...
# 45892  Jun012216558RT22        16558    11/5/2022      1/6/2022      4/6/2022
# 45893  Jun012216558RT23        16558    12/5/2022      1/6/2022      2/6/2022
# 45894  Jun012216558RT24        16558     27-05-22      1/6/2022      3/6/2022
# 45895  Jun012216558RT25        16558     29-05-22      1/6/2022      2/6/2022
# 45896  Jun012216558RT26        16558     29-05-22      1/6/2022      6/6/2022
#
# ...

# %%
df_bookings.shape
# Out:
# (45884, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    45884.000000
# mean     12681.892250
# std       6923.927394
# min       2600.000000
# 25%       7600.000000
# 50%      11700.000000
# 75%      15300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit=df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# 33453.67443303448

# %%
df_bookings[df_bookings.room_category=='RT4']
# Out:
#              booking_id  property_id booking_date check_in_date checkout_date  \
# 47     May012216558RT41        16558     26-04-22      1/5/2022      3/5/2022
# 48     May012216558RT42        16558     27-04-22      1/5/2022      2/5/2022
# 49     May012216558RT43        16558     29-04-22      1/5/2022      4/5/2022
# 137    May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
# 138    May012216559RT42        16559    11/4/2022      1/5/2022      3/5/2022
# ...                 ...          ...          ...           ...           ...
# 45877  May312217564RT42        17564     31-05-22      31-05-22      5/6/2022
# 45878  May312217564RT43        17564     28-05-22      31-05-22      5/6/2022
# 45879  May312217564RT44        17564     28-05-22      31-05-22      6/6/2022
# 45880  May312217564RT45        17564     27-05-22      31-05-22      2/6/2022
# 45881  May312217564RT46        17564     31-05-22      31-05-22      4/6/2022
#
# ...

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count     5475.000000
# mean     23404.342283
# std       9022.517697
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        26673
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %% [markdown]
# **Data Transformation**

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['Occ_pct']=df_agg_bookings['successful_bookings']/df_agg_bookings['capacity']

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     Occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_agg_bookings['Occ_pct']=df_agg_bookings['Occ_pct'].apply(lambda x:round(x*100,2))

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    Occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# Insights **Generation**

# %% [markdown]
# 1. What is an average occupacy rate in each of the room categories?

# %%
df_agg_bookings.groupby('room_category')['Occ_pct'].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: Occ_pct, dtype: float64

# %%
df=pd.merge(df_agg_bookings,df_room,left_on='room_category',right_on='room_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    Occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
df.groupby('room_class')['Occ_pct'].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: Occ_pct, dtype: float64

# %%
df.drop('room_id',axis=1,inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    Occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard
# 4    94.74   Standard

# %% [markdown]
# 2. Print average occupacy rate per city

# %%
df=pd.merge(df,df_hotel,on='property_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    Occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai
# 4    94.74   Standard   Atliq Grands    Luxury      Delhi

# %%
df.groupby('city')['Occ_pct'].mean().plot(kind='barh')
# Out:
# <Axes: ylabel='city'>

# %% [markdown]
# 3. when was the occupacy better? weekday or weekend?

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df=pd.merge(df,df_date,left_on='check_in_date',right_on='date')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    Occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 4    57.89   Standard  Atliq Grands    Luxury     Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# ...

# %%
df.groupby('day_type')['Occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: Occ_pct, dtype: float64

# %%
df.groupby('day_type')['Occ_pct'].mean().plot(kind='barh')
# Out:
# <Axes: ylabel='day_type'>

# %% [markdown]
# 4. In month of July, what is occupacy for different cities

# %%
df_jul=df[df["mmm yy"]=="Jul 22"]

# %%
df_jul.groupby('city')['Occ_pct'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        59.18
# Hyderabad    55.36
# Mumbai       55.24
# Bangalore    54.07
# Name: Occ_pct, dtype: float64

# %%
df_august=pd.read_csv('/content/new_data_august.csv')
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 14)

# %%
latest_df=pd.concat([df,df_august], ignore_index=True, axis=0)

latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       Occ_pct    room_class  property_name  category       city       date  \
# ...

# %% [markdown]
# 6. Print revenue realized per city

# %%
df_bookings_all=pd.merge(df_bookings,df_hotel,on='property_id')
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0             9100.0            3640.0  Atliq Grands   Luxury  Delhi
# 1            10920.0           10920.0  Atliq Grands   Luxury  Delhi
# 2             9100.0            9100.0  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby('city')['revenue_realized'].sum()
# Out:
# city
# Bangalore    143789940.0
# Delhi         99591072.0
# Hyderabad    111206640.0
# Mumbai       227308292.0
# Name: revenue_realized, dtype: float64

# %% [markdown]
# 7. Print month by month revenue

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45884 entries, 0 to 45883
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         45884 non-null  object
#  1   property_id        45884 non-null  int64
#  2   booking_date       45884 non-null  object
#  3   check_in_date      45884 non-null  object
#  4   checkout_date      45884 non-null  object
#  5   no_guests          45884 non-null  float64
#  6   room_category      45884 non-null  object
#  7   booking_platform   45884 non-null  object
#  8   ratings_given      19211 non-null  float64
#  9   booking_status     45884 non-null  object
#  10  revenue_generated  45884 non-null  float64
#  11  revenue_realized   45884 non-null  float64
#  12  property_name      45884 non-null  object
#  13  category           45884 non-null  object
#  14  city               45884 non-null  object
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_date['date']=pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
# <ipython-input-74-a70c5b712e71>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date['date']=pd.to_datetime(df_date["date"])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45884 entries, 0 to 45883
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         45884 non-null  object
#  1   property_id        45884 non-null  int64
#  2   booking_date       45884 non-null  object
#  3   check_in_date      45884 non-null  object
#  4   checkout_date      45884 non-null  object
#  5   no_guests          45884 non-null  float64
#  6   room_category      45884 non-null  object
#  7   booking_platform   45884 non-null  object
#  8   ratings_given      19211 non-null  float64
#  9   booking_status     45884 non-null  object
#  10  revenue_generated  45884 non-null  float64
#  11  revenue_realized   45884 non-null  float64
#  12  property_name      45884 non-null  object
#  13  category           45884 non-null  object
#  14  city               45884 non-null  object
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1             9100.0            3640.0
# 4            10920.0           10920.0
# 5             9100.0            9100.0

# %%
df_hotel.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %% [markdown]
# 7. Print revenue realized per hotel type

# %%
df_realized=pd.merge(df_bookings,df_hotel,on='property_id')
df_realized.groupby('property_name')['revenue_realized'].sum()
# Out:
# property_name
# Atliq Bay         88090833.0
# Atliq Blu         88933278.0
# Atliq City        97713924.0
# Atliq Exotica    108620658.0
# Atliq Grands      72775061.0
# Atliq Palace     103386654.0
# Atliq Seasons     22375536.0
# Name: revenue_realized, dtype: float64

# %% [markdown]
# 8. Print average rating per city

# %%
df_city=pd.merge(df_bookings,df_hotel,on='property_id')
df_city.groupby('city')['ratings_given'].mean().round(2)
# Out:
# city
# Bangalore    3.43
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.66
# Name: ratings_given, dtype: float64

# %% [markdown]
# 9. Print pie chart of revenue realized per booking platform

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0             9100.0            3640.0  Atliq Grands   Luxury  Delhi
# 1            10920.0           10920.0  Atliq Grands   Luxury  Delhi
# 2             9100.0            9100.0  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby('booking_platform')['revenue_realized'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='revenue_realized'>
